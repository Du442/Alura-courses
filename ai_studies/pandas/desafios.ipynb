# %% [markdown]
# ## Descrição
#
# Esse notebook foi construído para realizar os desafios propostos no final de cada aula do curso **Pandas: conhecendo a biblioteca**

# %% [markdown]
# ## Aula 1: Conhecendo a base de dados

# %% [markdown]
# ### Desafio 1
# Importe o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) e armazene seu conteúdo em um DataFrame Pandas

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

df = pd.read_csv(url, sep=';')

# %% [markdown]
# ### Desafio 2
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas

# %%
df.head(7)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN
# 5  1200.0         NaN     NaN
# 6  1300.0       301.0    17.0

# %%
df.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %% [markdown]
# ### Desafio 3
# Confira a quantidade de linhas e colunas do DataFrame

# %%
df.shape
# Out:
# (32960, 9)

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  str
#  1   Bairro      32960 non-null  str
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 2.3 MB

# %%
df['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: str

# %%
df['Vagas']
# Out:
# 0        0
# 1        0
# 2        4
# 3        0
# 4        0
#         ..
# 32955    0
# 32956    1
# 32957    1
# 32958    0
# 32959    0
# Name: Vagas, Length: 32960, dtype: int64

# %%
df['Condominio']
# Out:
# 0         500.0
# 1           NaN
# 2        4020.0
# 3         390.0
# 4         230.0
#           ...
# 32955     350.0
# 32956     800.0
# 32957     509.0
# 32958     760.0
# 32959    4206.0
# Name: Condominio, Length: 32960, dtype: float64

# %% [markdown]
# ### **Extra**
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc) - Dica: pesquise pelo método **describe**

# %%
df.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %% [markdown]
# ## Aula 2: Análise exploratória dos dados

# %% [markdown]
# Para os desafios dessa aula, vamos utilizar a mesma base de dados que estamos utilizando para o desenvolvimento do nosso projeto. Sendo assim, na célula abaixo vamos realizar a importação dessa base de dados e aplicar as transformações já realizadas até o momento da aula 2.

# %%
import pandas as pd

# %%
# importando a base de dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 
                      'Prédio Inteiro', 'Loja/Salão', 
                      'Galpão/Depósito/Armazém', 
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']
                      
# removendo imóveis comerciais
df = dados.query('@imoveis_comerciais not in Tipo')

# selecionando apenas imóveis do tipo apartamento
df = df.query('Tipo == "Apartamento"')

# visualizando a base de dados
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ### Desafio 1
# Calcular a média de quartos por apartamento

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

df = pd.read_csv(url, sep=';')

df['Quartos'].mean()
# Out:
# np.float64(1.7713895631067962)

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# ### Desafio 2
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
df.Bairro.unique()
# Out:
# <StringArray>
# [         'Copacabana',     'Jardim Botânico',     'Barra da Tijuca',
#               'Centro',        'Higienópolis',        'Vista Alegre',
#             'Cachambi',               'Ramos',              'Grajaú',
#  'Lins de Vasconcelos',
#  ...
#       'Cidade de Deus',    'Magalhães Bastos',         'Coelho Neto',
#        'Vasco da Gama',           'Bancários',        'Rio da Prata',
#        'Cidade Jardim',     'Parque Colúmbia',             'Grumari',
#             'Sepetiba']
# Length: 162, dtype: str

# %%
df.Bairro.value_counts()
# Out:
# Bairro
# Barra da Tijuca             6259
# Centro                      3258
# Copacabana                  3186
# Ipanema                     2233
# Recreio dos Bandeirantes    2127
#                             ...
# Rio da Prata                   1
# Cidade Jardim                  1
# Parque Colúmbia                1
# Grumari                        1
# Sepetiba                       1
# Name: count, Length: 162, dtype: int64

# %%
len(df['Bairro'].unique())
# Out:
# 162

# %% [markdown]
# ### Desafio 3
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
dados_agrupados = df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False)

dados_agrupados.head()
# Out:
#                        Valor
# Bairro
# Jacarepaguá    314143.489637
# Irajá          154610.470588
# Caju           120264.782609
# Vasco da Gama  120000.000000
# Cidade Nova     88166.692308

# %% [markdown]
# ### Desafio 4
# Criar um gráfico de barras verticais que apresente os 5 bairros com a média de valor de aluguel mais elevadas

# %%
df_agrupado = dados_agrupados = df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False).head()

df_agrupado.plot(kind='barh', figsize=(14,10), color='green')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# ## Aula 3
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

df = pd.read_csv(url, sep=',')

# %% [markdown]
# ### Desafio 1
# Verifique se a base de dados possui dados nulos e caso tenha, realize o tratamento desses dados nulos

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %%
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 2
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados

# %%
dados_removidos = df.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
df.drop(dados_removidos, axis=0, inplace=True)

# %%
df.query('Nome == "Alice" | Nome == "Carlos"')
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado]
# Index: []

# %%
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Aplique um filtro que selecione apenas os alunos que foram aprovados

# %%
selecao = df['Aprovado'] == True

df_aprovados = df[selecao]

# %%
df_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 4
# Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv"

# %%
df_aprovados.to_csv('alunos_aprovados.csv', index=False, sep=',')

# %%
alunos_aprovados = pd.read_csv('alunos_aprovados.csv', sep=',')

# %%
alunos_aprovados
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    7.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    7.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# ### **Extra**
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. **Dica**: pesquise pelo método **replace**

# %%
alunos_aprovados.replace(7.0, 8.0)
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    8.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    8.0      True
# 6      Nadia     34    8.0      True

# %%
alunos_aprovados = alunos_aprovados.replace(7.0, 8.0)

# %%
alunos_aprovados
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    8.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    8.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# ## Aula 4
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

df = pd.read_csv(url)

# %%
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 1
# Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles

# %%
pontos_extras = round(df['Notas'] * (df['Notas'] / 100), 2)

df['Pontos_extras'] = pontos_extras

# %%
df = df.fillna(0)
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True           0.56
# 1         Ana     18    0.0     False           0.00
# 2       Cátia     27    2.5     False           0.06
# 3       Denis     18    5.0     False           0.25
# 4        Beto     21   10.0      True           1.00
# 5       Bruna     23    0.0     False           0.00
# 6        Dara     21    7.0      True           0.49
# 7      Carlos     19    6.0      True           0.36
# 8       Alice     35    5.6     False           0.31
# 9       Vitor     28    0.0     False           0.00
# 10     Daniel     21    0.0     False           0.00
# 11       Igor     24    4.5     False           0.20
# 12  Sthefanie     26    9.5      True           0.90
# 13      Mirla     25    9.0      True           0.81
# 14      Paulo     37    0.0     False           0.00
# 15     Mylena     29    7.0      True           0.49
# 16      Lucas     33    0.0     False           0.00
# ...

# %% [markdown]
# ### Desafio 2
# Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras

# %%
df['Notas_Finais'] = df['Notas'] + df['Pontos_extras']

# %%
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais
# 0         Ary     20    7.5      True           0.56          8.06
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           0.06          2.56
# 3       Denis     18    5.0     False           0.25          5.25
# 4        Beto     21   10.0      True           1.00         11.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           0.49          7.49
# 7      Carlos     19    6.0      True           0.36          6.36
# 8       Alice     35    5.6     False           0.31          5.91
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           0.20          4.70
# 12  Sthefanie     26    9.5      True           0.90         10.40
# ...

# %% [markdown]
# ### Desafio 3
# Como os alunos ganharam pontos extras, alguns que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# * True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# * False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df['Aprovados_final'] = df['Notas_Finais'].apply(lambda x: "Aprovado" if x >= 6 else "Reprovado")

# %%
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais  \
# 0         Ary     20    7.5      True           0.56          8.06
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           0.06          2.56
# 3       Denis     18    5.0     False           0.25          5.25
# 4        Beto     21   10.0      True           1.00         11.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           0.49          7.49
# 7      Carlos     19    6.0      True           0.36          6.36
# 8       Alice     35    5.6     False           0.31          5.91
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           0.20          4.70
# 12  Sthefanie     26    9.5      True           0.90         10.40
# ...

# %% [markdown]
# ### Desafio 4
# Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras

# %%
df.query('Aprovado == False & Aprovados_final == True')
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado, Pontos_extras, Notas_Finais, Aprovados_final]
# Index: []

# %%
selecao = (df['Aprovado'] == False) & (df['Aprovados_final'] == True)
df[selecao]
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado, Pontos_extras, Notas_Finais, Aprovados_final]
# Index: []
