# %%
import pandas as pd

# %%
dados = pd.read_json('informacoes.json')
dados
# Out:
#    nome  idade                                          enderecos
# 0  João     28  {'tipo': 'casa', 'rua': 'Rua A', 'numero': 123...
# 1  João     28  {'tipo': 'trabalho', 'rua': 'Rua B', 'numero':...

# %%
import json

with open('informacoes.json') as f:
    dados = json.load(f)

informacoes = pd.json_normalize(data=dados, record_path='enderecos', meta=['nome', 'idade'], errors='ignore')

# %%
informacoes
# Out:
#        tipo    rua  numero          cidade   nome idade
# 0      casa  Rua A     123      SÃ£o Paulo  JoÃ£o    28
# 1  trabalho  Rua B     456  Rio de Janeiro  JoÃ£o    28

# %%
import pandas as pd
import json

# %%
with open('dados.json', 'r') as f:
    dados = json.load(f)

# %%
dados = pd.json_normalize(dados, record_path=['pessoas'])

# %%
dados['idade'] = dados['idade'].astype(int)

# %%
dados['telefones'] = dados['telefones'].astype(str)

# %%
dados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      str
#  1   idade            2 non-null      int64
#  2   telefones        2 non-null      str
#  3   endereco.rua     2 non-null      str
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      str
# dtypes: int64(2), str(4)
# memory usage: 228.0 bytes

# %%
dados.head()
# Out:
#     nome  idade                         telefones endereco.rua  \
# 0  JoÃ£o     25  ['11 1111-1111', '11 2222-2222']        Rua A
# 1  Maria     30                  ['21 3333-3333']
#
#    endereco.numero endereco.cidade
# 0              123      SÃ£o Paulo
# 1              456  Rio de Janeiro

# %%
dado_vazio = dados[dados['endereco.rua'] == ''].copy()

# %%
df_filtrado = dados[dados['endereco.rua'] != ""]

# %%
df_filtrado
# Out:
#     nome  idade                         telefones endereco.rua  \
# 0  JoÃ£o     25  ['11 1111-1111', '11 2222-2222']        Rua A
#
#    endereco.numero endereco.cidade
# 0              123      SÃ£o Paulo

# %% [markdown]
# <p>Exercicios aula 3</p>

# %%
import pandas as pd
import json

# %%
cursos = pd.read_json('cursos_cadastrados.json')

# %%
with open('cursos_cadastrados.json', 'r', encoding='utf-8') as f:
    cursos = json.load(f)

# %%
cursos = pd.json_normalize(cursos)

# %%
cursos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      str
#  1   categoria           6 non-null      str
#  2   carga_horaria       5 non-null      str
#  3   concluintes         5 non-null      object
#  4   data_inicio         5 non-null      str
#  5   data_conclusao      5 non-null      str
#  6   descricao           5 non-null      str
#  7   preco               5 non-null      object
#  8   instrutor.nome      6 non-null      str
#  9   instrutor.email     6 non-null      str
#  10  instrutor.telefone  6 non-null      str
# dtypes: object(2), str(9)
# memory usage: 660.0+ bytes

# %%
cursos['carga_horaria'] = cursos['carga_horaria'].fillna('10 horas', inplace=True)
# Out:
# C:\Users\eneto\AppData\Local\Temp\ipykernel_11112\1449180771.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cursos['carga_horaria'] = cursos['carga_horaria'].fillna('10 horas', inplace=True)

# %%
cursos['descricao'] = cursos['descricao'].fillna('Curso introdutório para Excel.')

# %%
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1         NaN            NaN
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                     Curso introdutório para Excel.   None  Maria Oliveira
# ...

# %%
cursos.at[3, "instrutor.nome"] = 'Teste'
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1         NaN            NaN
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                     Curso introdutório para Excel.   None  Maria Oliveira
# ...

# %%
cursos['preco'].isna()
cursos['preco'] = cursos['preco'].fillna(79.90)
cursos.head()
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1         NaN            NaN
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                     Curso introdutório para Excel.   79.9  Maria Oliveira
# 2                    Curso introdutório em marketing   89.9      Ana Santos
# ...

# %%
cursos['concluintes'] = cursos['concluintes'].fillna(80)
cursos['data_inicio'] = cursos['data_inicio'].fillna('2022-03-22')
cursos['data_conclusao'] = cursos['data_conclusao'].fillna('2022-04-16')

# %%
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas          80
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-22     2022-04-16
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                     Curso introdutório para Excel.   79.9  Maria Oliveira
# ...

# %%
cursos.head()
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas          80
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-22     2022-04-16
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                     Curso introdutório para Excel.   79.9  Maria Oliveira
# 2                    Curso introdutório em marketing   89.9      Ana Santos
# ...

# %%
cursos.at[3, "concluintes"] = 92
cursos.at[3, 'data_conclusao'] = '2022-04-26'
cursos.at[3, "instrutor.telefone"] = '(11) 6666-6666'

cursos.at[4, "data_inicio"] = '2022-07-18'
cursos.at[4, "data_conclusao"] = '2022-08-01'
cursos.at[4, "instrutor.email"] = 'testeteste@gmail.com'
cursos.at[4, "instrutor_telefone"] = '(11) 5555-5555'

# %%
cursos.at[4, 'instrutor.telefone'] = '(11) 5555-5555'
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade      10 horas          80
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas          92
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-22     2022-04-16
# 2  2022-03-01     2022-03-31
# 3  2022-04-01     2022-04-26
# 4  2022-07-18     2022-08-01
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# ...

# %%
cursos['carga_horaria'].values
# Out:
# array([list(['20']), list(['10']), list(['30']), list(['40']),
#        list(['20']), list(['20'])], dtype=object)

# %%
cursos['carga_horaria'] = cursos['carga_horaria'].explode()

# %%
cursos['carga_horaria'] = cursos['carga_horaria'].astype(int)

# %%
cursos['carga_horaria'].values
# Out:
# array([20, 10, 30, 40, 20, 20])

# %%
cursos['concluintes'] = cursos['concluintes'].astype(int)
cursos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      str
#  1   categoria           6 non-null      str
#  2   carga_horaria       6 non-null      int64
#  3   concluintes         6 non-null      int64
#  4   data_inicio         6 non-null      str
#  5   data_conclusao      6 non-null      str
#  6   descricao           6 non-null      str
#  7   preco               6 non-null      object
#  8   instrutor.nome      6 non-null      str
#  9   instrutor.email     6 non-null      str
#  10  instrutor.telefone  6 non-null      str
#  11  precos              6 non-null      object
#  12  instrutor_telefone  1 non-null      str
# dtypes: int64(2), object(2), str(9)
# memory usage: 756.0+ bytes

# %%
cursos['data_inicio'] = cursos['data_inicio'].astype('datetime64[us]')
cursos['data_conclusao'] = cursos['data_conclusao'].astype('datetime64[us]')

# %%
cursos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      str
#  1   categoria           6 non-null      str
#  2   carga_horaria       6 non-null      int64
#  3   concluintes         6 non-null      int64
#  4   data_inicio         6 non-null      datetime64[us]
#  5   data_conclusao      6 non-null      datetime64[us]
#  6   descricao           6 non-null      str
#  7   preco               6 non-null      object
#  8   instrutor.nome      6 non-null      str
#  9   instrutor.email     6 non-null      str
#  10  instrutor.telefone  6 non-null      str
#  11  precos              6 non-null      object
#  12  instrutor_telefone  1 non-null      str
# dtypes: datetime64[us](2), int64(2), object(2), str(7)
# memory usage: 756.0+ bytes

# %%
cursos['preco'].values
# Out:
# array(['99.90', 79.9, 89.9, 129.9, 69.9, '99.90'], dtype=object)

# %%
cursos['preco'] = pd.to_numeric(cursos['preco'])
cursos['preco'].values
cursos['preco'] = cursos['preco'].astype(float)
cursos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      str
#  1   categoria           6 non-null      str
#  2   carga_horaria       6 non-null      int64
#  3   concluintes         6 non-null      int64
#  4   data_inicio         6 non-null      datetime64[us]
#  5   data_conclusao      6 non-null      datetime64[us]
#  6   descricao           6 non-null      str
#  7   preco               6 non-null      float64
#  8   instrutor.nome      6 non-null      str
#  9   instrutor.email     6 non-null      str
#  10  instrutor.telefone  6 non-null      str
#  11  precos              6 non-null      object
#  12  instrutor_telefone  1 non-null      str
# dtypes: datetime64[us](2), float64(1), int64(2), object(1), str(7)
# memory usage: 756.0+ bytes

# %%
cursos
# Out:
#                              curso      categoria  carga_horaria  concluintes  \
# 0         Introdução à programação    Programação             20          100
# 1            Excel para iniciantes  Produtividade             10           80
# 2  Marketing digital para negócios      Marketing             30           75
# 3          Inteligência artificial    Programação             40           92
# 4             Inglês para negócios        Idiomas             20           30
# 5         Introdução à programação    Programação             20          100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-22     2022-04-16
# 2  2022-03-01     2022-03-31
# 3  2022-04-01     2022-04-26
# 4  2022-07-18     2022-08-01
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python   99.9      João Silva
# ...

# %%
cursos_clean = cursos

# %%
cursos_clean.drop(['instrutor_telefone'],axis=1, inplace=True)

# %%
cursos_clean
# Out:
#                              curso      categoria  carga_horaria  concluintes  \
# 0         Introdução à programação    Programação             20          100
# 1            Excel para iniciantes  Produtividade             10           80
# 2  Marketing digital para negócios      Marketing             30           75
# 3          Inteligência artificial    Programação             40           92
# 4             Inglês para negócios        Idiomas             20           30
# 5         Introdução à programação    Programação             20          100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-22     2022-04-16
# 2  2022-03-01     2022-03-31
# 3  2022-04-01     2022-04-26
# 4  2022-07-18     2022-08-01
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python   99.9      João Silva
# ...

# %%
cursos_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      str
#  1   categoria           6 non-null      str
#  2   carga_horaria       6 non-null      int64
#  3   concluintes         6 non-null      int64
#  4   data_inicio         6 non-null      datetime64[us]
#  5   data_conclusao      6 non-null      datetime64[us]
#  6   descricao           6 non-null      str
#  7   preco               6 non-null      float64
#  8   instrutor.nome      6 non-null      str
#  9   instrutor.email     6 non-null      str
#  10  instrutor.telefone  6 non-null      str
# dtypes: datetime64[us](2), float64(1), int64(2), str(6)
# memory usage: 660.0 bytes

# %% [markdown]
# <h3>Exercicios aula 4</h3>

# %%
import pandas as pd
import seaborn as sns

# criando um DataFrame com 30 transações aleatórias
df = pd.DataFrame({
    'ID da transação': range(1, 31),
    'Valor da transação': [100, 200, 150, 500, 300, 913, 250, 400, 200, 150, 
                           200, 200, 400, 300, 150, 301, 805, 300, 400, 250, 
                           150, 100, 500, 600, 200, 350, 100, 250, 800, 250],
    'Data da transação': pd.date_range(start='2022-01-01', end='2022-01-30', freq='D'),
    'Local da transação': ['São Paulo, Brasil', 'Rio de Janeiro, Brasil', 'Belo Horizonte, Brasil', 'São Paulo, Brasil', 
                           'São Paulo, Brasil', 'Nova Iorque, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'Rio de Janeiro, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Los Angeles, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Miami, EUA', 'São Paulo, Brasil']
})

# %%
df_sem_out = df.copy()

# %%
df_sem_out.reset_index(inplace=True, drop=True)

# %%
df_sem_out
# Out:
#     ID da transação  Valor da transação Data da transação  \
# 0                 1                 100        2022-01-01
# 1                 2                 200        2022-01-02
# 2                 3                 150        2022-01-03
# 3                 4                 500        2022-01-04
# 4                 5                 300        2022-01-05
# 5                 6                 913        2022-01-06
# 6                 7                 250        2022-01-07
# 7                 8                 400        2022-01-08
# 8                 9                 200        2022-01-09
# 9                10                 150        2022-01-10
# 10               11                 200        2022-01-11
# 11               12                 200        2022-01-12
# 12               13                 400        2022-01-13
# 13               14                 300        2022-01-14
# 14               15                 150        2022-01-15
# ...

# %%
def identificar_outlier(coluna, dataframe):
    Q1 = dataframe[coluna].quantile(.25)
    Q3 = dataframe[coluna].quantile(.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5*IQR
    limite_superior = Q3 + 1.5*IQR
    outliers = dataframe[(dataframe[coluna] < limite_inferior) | (dataframe[coluna] > limite_superior)]
    # outliers_index = (dataframe[coluna] < limite_inferir) | (dataframe[coluna] > limite_superior)
    
    return outliers
    # return dataframe[outliers_index][coluna], IQR, sns.boxplot(x=dataframe[coluna])

# %%
identificar_outlier('Valor da transação',df_sem_out)
# Out:
#     ID da transação  Valor da transação Data da transação Local da transação
# 5                 6                 913        2022-01-06   Nova Iorque, EUA
# 16               17                 805        2022-01-17   Los Angeles, EUA
# 28               29                 800        2022-01-29         Miami, EUA
